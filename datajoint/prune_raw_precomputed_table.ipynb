# %% [markdown]
# # prune_raw_precomputed_table
# The purpose of this notebook is to go through the production spock table containing the precomputed raw imaging pipeline job ids and get rid of the ones that do not correspond to entries in the ImagingChannel() table in the light sheet schema. This happened because I re-submitted the imaging entry form when there was an error. Somehow one of the raw data folders got overwritten so when it came time to run the precomputed raw pipeline on them, that failed. I moved the launching of the celery job to start the raw precomputed pipeline when an individual sample form is submitted so this should no longer be a problem in the future.

# %%
import pandas as pd
import numpy as np
import datajoint as dj
import matplotlib
import matplotlib.pyplot as plt
from datetime import datetime
matplotlib.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# <a id='connect'></a>
# # Connect to the datajoint00 database
# Username and password are same as Princeton login.
#
# **Note**: You need to be on campus or using a VPN to connect to the database.

# %%
netid = 'ahoag' # change this to your netid 
dj.config['database.host'] = 'datajoint00.pni.princeton.edu'
dj.config['database.user'] = netid
dj.conn()
# Out:
# Please enter DataJoint password: ········
# Connecting ahoag@datajoint00.pni.princeton.edu:3306
# DataJoint connection (connected) ahoag@datajoint00.pni.princeton.edu:3306

# %%
# db_lightsheet = dj.create_virtual_module('ahoag_lightsheet_demo','ahoag_lightsheet_demo')
# db_spockadmin = dj.create_virtual_module('ahoag_spockadmin_demo','ahoag_spockadmin_demo')

db_lightsheet = dj.create_virtual_module('a','u19lightserv_lightsheet')
db_spockadmin = dj.create_virtual_module('a','u19lightserv_appcore')

# %%
# Go through step2 jobids in the raw precomputed table 
lightsheets,spock_step2_jobids = db_spockadmin.RawPrecomputedSpockJob().fetch('lightsheet','jobid_step2')

# %%
raw_precomputed_contents = db_spockadmin.RawPrecomputedSpockJob()
raw_precomputed_contents
# Out:
# *jobid_step2   *timestamp     lightsheet     jobid_step0    jobid_step1    username     status_step0   status_step1   status_step2
# +------------+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+
# 20002337       2020-08-24 13: left           20002335       20002336       soline       SUBMITTED      SUBMITTED      SUBMITTED
# 20002337       2020-08-24 14: left           20002335       20002336       soline       COMPLETED      COMPLETED      COMPLETED
# 20002381       2020-08-24 14: right          20002379       20002380       soline       SUBMITTED      SUBMITTED      SUBMITTED
# 20002381       2020-08-24 14: right          20002379       20002380       soline       COMPLETED      COMPLETED      COMPLETED
# 20002385       2020-08-24 14: left           20002383       20002384       soline       SUBMITTED      SUBMITTED      SUBMITTED
# 20002385       2020-08-24 14: left           20002383       20002384       soline       COMPLETED      COMPLETED      COMPLETED
# 20002388       2020-08-24 14: right          20002386       20002387       soline       SUBMITTED      SUBMITTED      SUBMITTED
# 20002388       2020-08-24 14: right          20002386       20002387       soline       COMPLETED      COMPLETED      COMPLETED
# 20010217       2020-08-26 16: left           20010211       20010214       oostland     SUBMITTED      SUBMITTED      SUBMITTED
# 20010217       2020-08-27 21: left           20010211       20010214       oostland     COMPLETED      COMPLETED      COMPLETED
# 20010218       2020-08-26 16: right          20010210       20010213       oostland     SUBMITTED      SUBMITTED      SUBMITTED
# 20010218       2020-08-27 21: right          20010210       20010213       oostland     COMPLETED      COMPLETED      COMPLETED
#    ...
#  (Total: 1123)

# %%
# for each one if there is not an entry in the ImagingChannel() table then remove this entry
left_precomputed_jobids,right_precomputed_jobids = db_lightsheet.Request.ImagingChannel().fetch(
    'left_lightsheet_precomputed_spock_jobid','right_lightsheet_precomputed_spock_jobid')

# %%
bad_spock_step2_jobids = []
for ii in range(len(spock_step2_jobids)):
    lightsheet = lightsheets[ii]
    spock_step2_jobid = spock_step2_jobids[ii]
    if lightsheet=='left':
        if spock_step2_jobid not in left_precomputed_jobids:
            bad_spock_step2_jobids.append(spock_step2_jobid)
    if lightsheet == 'right':
        if spock_step2_jobid not in right_precomputed_jobids:
            bad_spock_step2_jobids.append(spock_step2_jobid)
bad_spock_step2_jobids
# Out:
# ['20383040',
#  '20383047',
#  '20383048',
#  '20383049',
#  '20383056',
#  '20383057',
#  '20383058',
#  '20383064',
#  '20383066',
#  '20383067',
#  '20383073',
#  '20383074',
#  '20383076',
#  '20383083',
#  '20383084',
#  '20383085',
#  '20383090',
#  '20383093',
#  '20383094',
#  '20383101',
#  '20383102',
#  '20383103',
#  '20383110',
#  '20383111',
#  '20383112',
#  '20383119',
#  '20383120',
#  '20383121',
#  '20383127',
#  '20383129',
#  '20383130',
#  '20383137',
#  '20383138',
#  '20383139',
#  '20383145',
#  '20383147',
#  '20383148',
#  '20383155',
#  '20383156',
#  '20383157',
#  '20383162',
#  '20383165',
#  '20383166',
#  '20383171',
#  '20383172',
#  '20383175',
#  '20383181',
#  '20383183',
#  '20383184',
#  '20383191',
#  '20383192',
#  '20383193',
#  '20383200',
#  '20383201',
#  '20383202',
#  '20383391',
#  '20383392',
#  '20383395',
#  '20383398',
#  '20383404',
#  '20383406',
#  '20383407',
#  '20383410',
#  '20383413',
#  '20383418',
#  '20383419',
#  '20383422',
#  '20383425',
#  '20383430',
#  '20383431',
#  '20383434',
#  '20383437',
#  '20383442',
#  '20383443',
#  '20383446',
#  '20383450',
#  '20383454',
#  '20383455',
#  '20383458',
#  '20383462',
#  '20383466',
#  '20383467',
#  '20383470',
#  '20383473',
#  '20383478',
#  '20383479',
#  '20383482',
#  '20383485',
#  '20383488',
#  '20383491',
#  '20383494',
#  '20383497',
#  '20383500',
#  '20383503',
#  '20383506',
#  '20383512',
#  '20383514',
#  '20383515',
#  '20383518',
#  '20383525',
#  '20383526',
#  '20383527',
#  '20383530',
#  '20383537',
#  '20383538',
#  '20383539',
#  '20383542',
#  '20383546',
#  '20383550',
#  '20383551',
#  '20383554',
#  '20383561',
#  '20383562',
#  '20383563',
#  '20383566',
#  '20383571',
#  '20383575',
#  '20383578',
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383437
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383442
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383443
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383446
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383450
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383454
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383455
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383458
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383462
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383466
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383467
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383470
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383473
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383478
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383479
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383482
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383485
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383488
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383491
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383494
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383497
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383500
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383503
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383506
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383512
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383514
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383515
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383518
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383525
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383526
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383527
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383530
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383537
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383538
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383539
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383542
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383546
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383550
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383551
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383554
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383561
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383562
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383563
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383566
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383571
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383575
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383578
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383580
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383586
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383588
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383591
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383592
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383597
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383600
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383603
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383604
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383610
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383612
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383614
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383616
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383624
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383625
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383626
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383628
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383636
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383637
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383639
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383640
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383647
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383650
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383651
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383652
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383657
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383658
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383663
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383664
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383673
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383674
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383675
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383676
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383682
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383686
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383687
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383688
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383696
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383698
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383699
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383700
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383707
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383710
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383711
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383712
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383719
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383720
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383723
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383724
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383733
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383734
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383735
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383736
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383742
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383746
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383747
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20383748
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415815
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415816
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415819
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415822
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415826
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415830
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415831
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415834
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415840
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415841
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415844
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415846
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415853
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415854
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415855
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415858
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415867
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415868
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415869
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415870
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415879
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415880
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415881
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415882
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415886
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415891
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415893
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415894
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415902
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415903
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415905
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415906
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415913
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415916
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415917
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415918
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415927
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415928
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415929
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415930
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415939
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415940
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415941
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415942
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415949
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415950
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415953
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415954
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415961
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415964
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415965
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415966
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415975
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415976
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415977
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415978
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415987
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415988
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415989
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20415990
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20416166
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20416167
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20416168
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.
# 20416171
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 1 items
# Committed.

# %%
dj.config['safemode']=False
spock_table_contents.delete()

# %%
contents = db_spockadmin.RawPrecomputedSpockJob() & 'jobid_step2=18986528'
contents
# Out:
# *jobid_step2   *timestamp     lightsheet     jobid_step0    jobid_step1    username       status_step0   status_step1   status_step2
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 18986528       2020-05-15 18: left           18986521       18986524       lightserv-test SUBMITTED      SUBMITTED      SUBMITTED
# 18986528       2020-06-05 09: left           18986521       18986524       lightserv-test COMPLETED      CANCELLED      CANCELLED
#  (Total: 2)

# %%
contents.delete()
# Out:
# `u19lightserv_appcore`.`raw_precomputed_spock_job`: 2 items
# Committed.

# %%
spock_table_contents

# %%
spock_table_contents = db_spockadmin.RawPrecomputedSpockJob() & f'jobid_step2=18986528'
spock_table_contents

# %%
bool("False")

# %%
spock_table_contents = db_spockadmin.RawPrecomputedSpockJob()
spock_table_contents

# %%
job_contents = db_spockadmin.RawPrecomputedSpockJob()
unique_contents = dj.U('jobid_step2','username',).aggr(
    job_contents,timestamp='max(timestamp)')*job_contents

# %%
ongoing_codes = ('SUBMITTED','RUNNING','PENDING','REQUEUED','RESIZING','SUSPENDED')
incomplete_contents = unique_contents & f'status_step2 in {ongoing_codes}'

# %%
incomplete_contents

# %%
jobids = list(incomplete_contents.fetch('jobid_step2'))

# %%
jobids

# %%
'20382672' in jobids

# %%
list(incomplete_contents.fetch('username'))
