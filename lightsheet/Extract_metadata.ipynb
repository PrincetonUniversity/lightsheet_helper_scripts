# %% [markdown]
# # Extract_metadata
# In this notebook, we will look at how to extract image metadata from the Z=0 plane of raw light sheet microscope data.

# %%
import tifffile
from xml.etree import ElementTree as ET

# %%
# Example Z=0 raw file
raw_file = '/home/wanglab/mounts/LightSheetData/brodyatlas/raw_data/190719_brodylabatlas_p154_1d3x_488_017na_1hfds_z25um_50msec_40povlp_12-30-40/12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif'

# %%
# Grab the metadata tags
with tifffile.TiffFile(raw_file) as tif:
    tags = tif.pages[0].tags
tags.keys()
# Out:
# dict_keys(['ImageWidth', 'ImageLength', 'BitsPerSample', 'Compression', 'PhotometricInterpretation', 'DocumentName', 'ImageDescription', 'Make', 'Model', 'StripOffsets', 'Orientation', 'SamplesPerPixel', 'RowsPerStrip', 'StripByteCounts', 'PlanarConfiguration', 'DateTime', 'ImageDepth'])

# %%
# Try to access one, but notice that dictionary values are TiffTag() objects
tags['ImageWidth']

# %%
# To actually extract info use
tag = tags['ImageWidth']
print(tag.value)
# Out:
# 2160

# %% [markdown]
# ## Example: get the pixel size in x,y,z dimensions

# %%
# That info lives in a very long xml string stored in the 'ImageDescription' tag
xml_description=tags['ImageDescription'].value
# Print out first 1000 characters
xml_description[0:1000]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2008-02" xmlns:ca="http://www.openmicroscopy.org/Schemas/CA/2008-02" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2008-02 http://www.openmicroscopy.org/Schemas/OME/2008-02/ome.xsd" UUID="urn:uuid:A95A6E44-8957-42B2-AECB-25CBA04671B4">\r\n<Experimenter ID="Experimenter:not_specified_not_specified">\r\n<FirstName>not_specified</FirstName>\r\n<LastName>not_specified</LastName>\r\n<Email>not_specified</Email>\r\n<Institution>not_specified</Institution>\r\n</Experimenter>\r\n<Group ID="urn:lsid:imspector.group.id:Group:not_specified" Name="not_specified"/>\r\n<Image ID="Image:C7C8D108-5293-4305-89A6-D270686389B6" Name="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif" DefaultPixels="Pixels:C7C8D108-5293-4305-89A6-D270686389B6">\r\n<CreationDate>2019-07-19T12:42:28</CreationDate>\r\n<Description>not_specified</'

# %%
# Parse the xml using ElementTree
root = ET.fromstring(xml_description)
print(root)
# Out:
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}OME' at 0x7f82e00e4278>

# %%
# The tree is graph-like so to access further down the tree loop through children of root node
for child in root:
    print(child.tag,child.attrib)
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Experimenter {'ID': 'Experimenter:not_specified_not_specified'}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Group {'ID': 'urn:lsid:imspector.group.id:Group:not_specified', 'Name': 'not_specified'}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Image {'ID': 'Image:C7C8D108-5293-4305-89A6-D270686389B6', 'Name': '12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif', 'DefaultPixels': 'Pixels:C7C8D108-5293-4305-89A6-D270686389B6'}
# {http://www.openmicroscopy.org/Schemas/CA/2008-02}CustomAttributes {}

# %%
# The "Image" tag, i.e. root[2] is the one we want to expand
for child in root[2]:
    print(child.tag,child.attrib)
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}CreationDate {}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Description {}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Pixels {'ID': 'Pixels:C7C8D108-5293-4305-89A6-D270686389B6', 'DimensionOrder': 'XYCZT', 'PixelType': 'uint16', 'BigEndian': 'false', 'SizeX': '2160', 'SizeY': '2560', 'SizeZ': '281', 'SizeT': '1', 'SizeC': '2', 'PhysicalSizeX': '5.000000', 'PhysicalSizeY': '5.000000', 'PhysicalSizeZ': '25.000000'}
# {http://www.openmicroscopy.org/Schemas/CA/2008-02}CustomAttributes {}

# %%
# The pixel size is in the PhysicalSizeX, PhysicalSizeY, PhysicalSizeZ attributes, which are in the "Pixels" tag
image_tag = root[2]
pixel_tag = image_tag[2]
pixel_dict = pixel_tag.attrib
print(pixel_dict['PhysicalSizeX'],pixel_dict['PhysicalSizeY'],pixel_dict['PhysicalSizeZ'])
# Out:
# 5.000000 5.000000 25.000000

# %%
# To get a better sense of what is stored in the xml description file, you can either save the xml as a file with 
# Extension .xml and then load it in a browser, or do:
import xml.dom.minidom
xmlstr = xml.dom.minidom.parseString(ET.tostring(root)).toprettyxml()
print(xmlstr)
# Out:
# <?xml version="1.0" ?>
# <ns0:OME UUID="urn:uuid:A95A6E44-8957-42B2-AECB-25CBA04671B4" xmlns:ns0="http://www.openmicroscopy.org/Schemas/OME/2008-02" xmlns:ns2="http://www.openmicroscopy.org/Schemas/CA/2008-02" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2008-02 http://www.openmicroscopy.org/Schemas/OME/2008-02/ome.xsd">
#
#
# 	<ns0:Experimenter ID="Experimenter:not_specified_not_specified">
#
#
# 		<ns0:FirstName>not_specified</ns0:FirstName>
#
#
# 		<ns0:LastName>not_specified</ns0:LastName>
#
#
# 		<ns0:Email>not_specified</ns0:Email>
#
#
# 		<ns0:Institution>not_specified</ns0:Institution>
#
#
# 	</ns0:Experimenter>
#
#
# 	<ns0:Group ID="urn:lsid:imspector.group.id:Group:not_specified" Name="not_specified"/>
#
#
# 	<ns0:Image DefaultPixels="Pixels:C7C8D108-5293-4305-89A6-D270686389B6" ID="Image:C7C8D108-5293-4305-89A6-D270686389B6" Name="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif">
#
#
# 		<ns0:CreationDate>2019-07-19T12:42:28</ns0:CreationDate>
#
#
# 		<ns0:Description>not_specified</ns0:Description>
#
#
# 		<ns0:Pixels BigEndian="false" DimensionOrder="XYCZT" ID="Pixels:C7C8D108-5293-4305-89A6-D270686389B6" PhysicalSizeX="5.000000" PhysicalSizeY="5.000000" PhysicalSizeZ="25.000000" PixelType="uint16" SizeC="2" SizeT="1" SizeX="2160" SizeY="2560" SizeZ="281">
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="0">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif">urn:uuid:A95A6E44-8957-42B2-AECB-25CBA04671B4</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="0">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0000_UltraII Filter0000.ome.tif">urn:uuid:98D0283C-79A7-4FA4-9BB4-F0C456E0EBAF</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="1">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0001_UltraII Filter0000.ome.tif">urn:uuid:821AA761-24F9-471F-90BE-C208C8F18870</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="1">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0001_UltraII Filter0000.ome.tif">urn:uuid:52EBF253-23F9-4BB6-9E65-C9EF0B07B0F5</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="2">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0002_UltraII Filter0000.ome.tif">urn:uuid:399AC8FC-CB47-4D8C-A6B6-AA247AFD59C9</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="2">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0002_UltraII Filter0000.ome.tif">urn:uuid:67FB2669-250F-48CB-B1F0-CCC7506D7FF2</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="3">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0003_UltraII Filter0000.ome.tif">urn:uuid:F301BE6D-9C22-41CD-BEF3-AD091EDE4713</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="3">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0003_UltraII Filter0000.ome.tif">urn:uuid:943DA56F-6D98-4087-ADF3-F5AF5F9C6567</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="4">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0004_UltraII Filter0000.ome.tif">urn:uuid:EFB5147E-49E1-4B6D-84A8-FCF33E8410F0</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="4">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0004_UltraII Filter0000.ome.tif">urn:uuid:399583D7-FB4B-4EB4-94E7-C7A3641A3752</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="5">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0005_UltraII Filter0000.ome.tif">urn:uuid:9DA634ED-2111-4CB1-BFE2-2A4A32CF984B</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ
ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="275">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0275_UltraII Filter0000.ome.tif">urn:uuid:6A3671B6-1309-4B93-A88F-3F34A97CB516</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="275">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0275_UltraII Filter0000.ome.tif">urn:uuid:0382774D-1542-4112-B276-B4F1E73942EB</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="276">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0276_UltraII Filter0000.ome.tif">urn:uuid:D18291FD-D2DB-4436-B686-F847BC49491F</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="276">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0276_UltraII Filter0000.ome.tif">urn:uuid:73DFA40A-FDE5-4622-AB08-61A299B553A8</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="277">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0277_UltraII Filter0000.ome.tif">urn:uuid:B347AB45-72EE-47CF-8526-6A32437A9A67</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="277">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0277_UltraII Filter0000.ome.tif">urn:uuid:8D37AEF7-2CC7-40B1-A71B-CA5A4958E4BD</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="278">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0278_UltraII Filter0000.ome.tif">urn:uuid:FE5DB2A5-C890-4D3F-ABC0-7CF4C45006D2</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="278">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0278_UltraII Filter0000.ome.tif">urn:uuid:36E2A92F-07AE-4C49-A57A-7AD44A26247E</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="279">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0279_UltraII Filter0000.ome.tif">urn:uuid:E3D698FD-6248-43A5-8000-9BD70104DF72</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="279">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0279_UltraII Filter0000.ome.tif">urn:uuid:D546F0E2-3DC7-490A-BCF6-59DC6B874E9E</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="280">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0280_UltraII Filter0000.ome.tif">urn:uuid:0F00A26A-51B2-4339-B4CE-4627EEC84BCD</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="280">
#
#
# 				<ns0:UUID FileName="12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0280_UltraII Filter0000.ome.tif">urn:uuid:381FB0F3-BFA2-4CF9-A737-BC390F0E21C4</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:Channel ID="Channel:0" SamplesPerPixel="1"/>
#
#
# 		</ns0:Pixels>
#
#
# 		<ns2:CustomAttributes>
#
#
# 			<ns0:Offset Offset_0="-3487.264893" Offset_1="7815.293945" Offset_2="0.0" Offset_3="0.0"/>
#
#
# 			<ns0:Axis0 AxisName="xyz-Table Z" Offset="-3500.000000" PhysicalUnit="-25.000000" Steps="281"/>
#
#
# 			<ns0:Length Length_0="10800.000000" Length_1="12800.000000" Length_2="1.000000" Length_3="1.000000"/>
#
#
# 			<ns0:AxesLabels FirstAxis="None" FirstAxis-Unit="" SecondAxis="NONE" SecondAxis-Unit="" X="None" X-Unit="" Y="None" Y-Unit=""/>
#
#
# 			<ns0:dSel T0="0" T1="-1" X0="0" X1="-1" Y0="0" Y1="-1" Z0="0" Z1="-1"/>
#
#
# 			<ns0:dStampJmp dStampJmp0="0" dStampJmp1="0" dStampJmp2="0" dStampJmp3="0"/>
#
#
# 			<ns0:dStampRes dStampRes0="0" dStampRes1="0" dStampRes2="0" dStampRes3="0"/>
#
#
# 			<ns0:sDeviceKey sDeviceKey=""/>
#
#
# 			<ns0:dDisplayMode dDisplayMode="-1"/>
#
#
# 			<ns0:dHideMode dHideMode="-1"/>
#
#
# 			<ns0:dHideAxis dHideAxis="-1"/>
#
#
# 			<ns0:ColorMap ColorMap="0"/>
#
#
# 			<ns0:InstrumentMode InstrumentMode="not_specified"/>
#
#
# 			<ns0:MeasurementMode MeasurementMode="not_specified"/>
#
#
# 			<ns0:Rating Rating="0"/>
#
#
# 			<ns0:UseMetaDataGlobal UseMetaDataGlobal="1"/>
#
#
# 			<ns0:ImspectorVersion ImspectorVersion="Imspector Pro "/>
#
#
# 			<ns0:ObjectiveID ObjectiveID="not_specified"/>
#
#
# 			<ns0:ObjectiveNA ObjectiveNA="not_specified"/>
#
#
# 			<ns0:ObjectiveMedium ObjectiveMedium="not_specified"/>
#
#
# 			<ns0:IsPartOfMosaic IsPartOfMosaic="1"/>
#
#
# 			<ns0:TileConfiguration TileConfiguration="2   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,0.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0000_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,0.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0001_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-25.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0001_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-25.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0002_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-50.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0002_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-50.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0003_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-75.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0003_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-75.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0004_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-100.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0004_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-100.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0005_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-125.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0005_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-125.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0006_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-150.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0006_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-150.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0007_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-175.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0007_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-175.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0008_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-200.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0008_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-200.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0009_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-225.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0009_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-225.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0010_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-250.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0010_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-250.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0011_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-275.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0011_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-275.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0012_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-300.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0012_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,1,-300.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0013_UltraII Filter0000.ome.tif;;(-3487.264893, 7815.293945,0,-325.000000,0.000000)   12-30-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0013_UltraII Filt ...
#
#
# 			<ns0:Timestamps/>
#
#
# 		</ns2:CustomAttributes>
#
#
# 	</ns0:Image>
#
#
# 	<ns2:CustomAttributes>
#
#
# 		<ns0:PropArray>
#
#
# 			<ns0:Label Value="RawDataStack" fname="Label" nId="524288" nTy="5"/>
#
#
# 		</ns0:PropArray>
#
#
# 	</ns2:CustomAttributes>
#
#
# </ns0:OME>

# %% [markdown]
# ## Example: get experimenter information (netid)

# %%
# The experimenter info is in the Experimenter tag:
exp_tag = root[0]
for child in exp_tag:
    print(child,child.attrib)
# Out:
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}FirstName' at 0x7f82e00e4408> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}LastName' at 0x7f82e00e4458> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}Email' at 0x7f82e00e44a8> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}Institution' at 0x7f82e00e44f8> {}

# %%
# Here we see the attrib dict is empty, so how do we actually extract the email?
email_tag = exp_tag[2]
print(dir(email_tag))
# Out:
# ['__class__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'attrib', 'clear', 'extend', 'find', 'findall', 'findtext', 'get', 'getchildren', 'getiterator', 'insert', 'items', 'iter', 'iterfind', 'itertext', 'keys', 'makeelement', 'remove', 'set', 'tag', 'tail', 'text']

# %%
email_tag.text
# Out:
# 'not_specified'

# %% [markdown]
# ## Save the metadata xml file and view it in a browser (best option for viewing)

# %%
# Just need to write the xml string to a file
import os
output_filename = '/home/wanglab/Desktop/example_lightsheet_metadata.xml'
if not os.path.exists(output_filename):
    with open(output_filename,'w') as outfile:
        outfile.write(xml_description)
print("wrote %s" % output_filename)
# Out:
# wrote /home/wanglab/Desktop/example_lightsheet_metadata.xml
