# %% [markdown]
# # Extract_metadata
# In this notebook, we will look at how to extract image metadata from the Z=0 plane of raw light sheet microscope data.

# %%
import tifffile
from xml.etree import ElementTree as ET

# %%
# Example Z=0 raw file
raw_file = '/jukebox/LightSheetTransfer/brody/191031_e111_1_1x_488_008na_1hfds_z10um_100msec_60povlp_16-57-24/16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif'

# %%
# Grab the metadata tags
with tifffile.TiffFile(raw_file) as tif:
    tags = tif.pages[0].tags
tags.keys()
# Out:
# dict_keys(['ImageWidth', 'ImageLength', 'BitsPerSample', 'Compression', 'PhotometricInterpretation', 'DocumentName', 'ImageDescription', 'Make', 'Model', 'StripOffsets', 'Orientation', 'SamplesPerPixel', 'RowsPerStrip', 'StripByteCounts', 'PlanarConfiguration', 'DateTime', 'ImageDepth'])

# %%
# Try to access one, but notice that dictionary values are TiffTag() objects
tags['ImageWidth']

# %%
# To actually extract info use
tag = tags['ImageWidth']
print(tag.value)
# Out:
# 2160

# %% [markdown]
# ## Example: get the pixel size in x,y,z dimensions

# %%
# That info lives in a very long xml string stored in the 'ImageDescription' tag
xml_description=tags['ImageDescription'].value
# Print out first 1000 characters
xml_description[0:1000]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2008-02" xmlns:ca="http://www.openmicroscopy.org/Schemas/CA/2008-02" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2008-02 http://www.openmicroscopy.org/Schemas/OME/2008-02/ome.xsd" UUID="urn:uuid:9486A33E-5005-4614-B0DB-89C1E338D0A5">\r\n<Experimenter ID="Experimenter:not_specified_not_specified">\r\n<FirstName>not_specified</FirstName>\r\n<LastName>not_specified</LastName>\r\n<Email>not_specified</Email>\r\n<Institution>not_specified</Institution>\r\n</Experimenter>\r\n<Group ID="urn:lsid:imspector.group.id:Group:not_specified" Name="not_specified"/>\r\n<Image ID="Image:A4C8152E-3001-4001-AA32-4914EAE1EE30" Name="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif" DefaultPixels="Pixels:A4C8152E-3001-4001-AA32-4914EAE1EE30">\r\n<CreationDate>2019-10-31T17:34:42</CreationDate>\r\n<Description>not_specified</'

# %%
# Parse the xml using ElementTree
root = ET.fromstring(xml_description)
print(root)
# Out:
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}OME' at 0x7f5d5f9f1138>

# %%
# The tree is graph-like so to access further down the tree loop through children of root node
for child in root:
    print(child.tag,child.attrib)
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Experimenter {'ID': 'Experimenter:not_specified_not_specified'}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Group {'ID': 'urn:lsid:imspector.group.id:Group:not_specified', 'Name': 'not_specified'}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Image {'ID': 'Image:A4C8152E-3001-4001-AA32-4914EAE1EE30', 'Name': '16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif', 'DefaultPixels': 'Pixels:A4C8152E-3001-4001-AA32-4914EAE1EE30'}
# {http://www.openmicroscopy.org/Schemas/CA/2008-02}CustomAttributes {}

# %%
# The "Image" tag, i.e. root[2] is the one we want to expand
for child in root[2]:
    print(child.tag,child.attrib)
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}CreationDate {}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Description {}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Pixels {'ID': 'Pixels:A4C8152E-3001-4001-AA32-4914EAE1EE30', 'DimensionOrder': 'XYCZT', 'PixelType': 'uint16', 'BigEndian': 'false', 'SizeX': '2160', 'SizeY': '2560', 'SizeZ': '920', 'SizeT': '1', 'SizeC': '2', 'PhysicalSizeX': '5.909091', 'PhysicalSizeY': '5.909091', 'PhysicalSizeZ': '10.000000'}
# {http://www.openmicroscopy.org/Schemas/CA/2008-02}CustomAttributes {}

# %%
# The pixel size is in the PhysicalSizeX, PhysicalSizeY, PhysicalSizeZ attributes, which are in the "Pixels" tag
image_tag = root[2]
pixel_tag = image_tag[2]
pixel_dict = pixel_tag.attrib
print(pixel_dict['PhysicalSizeX'],pixel_dict['PhysicalSizeY'],pixel_dict['PhysicalSizeZ'])
# Out:
# 5.909091 5.909091 10.000000

# %%
# To get a better sense of what is stored in the xml description file, you can either save the xml as a file with 
# Extension .xml and then load it in a browser, or do:
import xml.dom.minidom
xmlstr = xml.dom.minidom.parseString(ET.tostring(root)).toprettyxml()
print(xmlstr)
# Out:
# <?xml version="1.0" ?>
# <ns0:OME UUID="urn:uuid:9486A33E-5005-4614-B0DB-89C1E338D0A5" xmlns:ns0="http://www.openmicroscopy.org/Schemas/OME/2008-02" xmlns:ns2="http://www.openmicroscopy.org/Schemas/CA/2008-02" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2008-02 http://www.openmicroscopy.org/Schemas/OME/2008-02/ome.xsd">
#
#
# 	<ns0:Experimenter ID="Experimenter:not_specified_not_specified">
#
#
# 		<ns0:FirstName>not_specified</ns0:FirstName>
#
#
# 		<ns0:LastName>not_specified</ns0:LastName>
#
#
# 		<ns0:Email>not_specified</ns0:Email>
#
#
# 		<ns0:Institution>not_specified</ns0:Institution>
#
#
# 	</ns0:Experimenter>
#
#
# 	<ns0:Group ID="urn:lsid:imspector.group.id:Group:not_specified" Name="not_specified"/>
#
#
# 	<ns0:Image DefaultPixels="Pixels:A4C8152E-3001-4001-AA32-4914EAE1EE30" ID="Image:A4C8152E-3001-4001-AA32-4914EAE1EE30" Name="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif">
#
#
# 		<ns0:CreationDate>2019-10-31T17:34:42</ns0:CreationDate>
#
#
# 		<ns0:Description>not_specified</ns0:Description>
#
#
# 		<ns0:Pixels BigEndian="false" DimensionOrder="XYCZT" ID="Pixels:A4C8152E-3001-4001-AA32-4914EAE1EE30" PhysicalSizeX="5.909091" PhysicalSizeY="5.909091" PhysicalSizeZ="10.000000" PixelType="uint16" SizeC="2" SizeT="1" SizeX="2160" SizeY="2560" SizeZ="920">
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="0">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif">urn:uuid:9486A33E-5005-4614-B0DB-89C1E338D0A5</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="0">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0000_UltraII Filter0000.ome.tif">urn:uuid:4D2B8F7E-60C1-4792-AA93-A759BFAEFB7F</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="1">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0001_UltraII Filter0000.ome.tif">urn:uuid:7B565744-B6E0-4024-8AE5-92DDA23CBF0B</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="1">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0001_UltraII Filter0000.ome.tif">urn:uuid:5A4B5FC3-FF7A-4800-97EE-261C04D2B539</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="2">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0002_UltraII Filter0000.ome.tif">urn:uuid:6A2B813C-60D7-45E4-AF38-3FC01C13872E</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="2">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0002_UltraII Filter0000.ome.tif">urn:uuid:B8AA74E0-26F6-4DE2-85B0-C112D86D2BC4</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="3">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0003_UltraII Filter0000.ome.tif">urn:uuid:D8C167F1-6EFD-45E5-9C83-CB2B043D3AF4</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="3">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0003_UltraII Filter0000.ome.tif">urn:uuid:0A5BCA43-2AC5-4B94-A762-C7AA49B9EF02</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="4">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0004_UltraII Filter0000.ome.tif">urn:uuid:7C0DE215-221D-4F15-A6A9-DCFEB8FCFF39</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="4">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0004_UltraII Filter0000.ome.tif">urn:uuid:B852094E-6D95-44AB-81CA-A5951D6F2F68</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="5">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0005_UltraII Filter0000.ome.tif">urn:uuid:2E4CA82C-72EE-41E2-982C-87BE810B36AD</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="5">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0005_UltraII Filter0000.ome.tif">urn:uuid:EC44808D-E25A-4F79-8B1F-24C3BECDC5E7</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="6">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0006_UltraII Filter0000.ome.tif">urn:uuid:3CFDB546-BD1D-46B1-9DAE-72E5F6376918</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="6">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0006_UltraII Filter0000.ome.tif">urn:uuid:D3DDF3EC-6798-47CE-AED9-678819B45954</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="7">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0007_UltraII Filter0000.ome.tif">urn:uuid:F176DDBC-681D-45DF-9180-BD817C1F0143</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="7">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0007_UltraII Filter0000.ome.tif">urn:uuid:5F404D6E-A86C-48FB-8318-AFFEE78ACCBD</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="8">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0008_UltraII Filter0000.ome.tif">urn:uuid:6D479917-8CDA-43CB-BC87-283118A6919A</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="8">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0008_UltraII Filter0000.ome.tif">urn:uuid:3039145E-C988-4CAE-A28B-9966FE1DA448</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="9">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0009_UltraII Filter0000.ome.tif">urn:uuid:297DB247-3494-4DD4-BFCC-92707B314A62</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="9">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0009_UltraII Filter0000.ome.tif">urn:uuid:2FB55EC3-615A-4C59-81EE-1E167357EDE2</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="10">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0010_UltraII Filter0000.ome.tif">urn:uuid:6C84F015-A26E-4941-B298-492B91C4099A</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="10">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0010_UltraII Filter0000.ome.tif">urn:uuid
ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="85">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0085_UltraII Filter0000.ome.tif">urn:uuid:60233B7D-6F50-4BCD-972D-33255F0971E7</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="85">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0085_UltraII Filter0000.ome.tif">urn:uuid:88B59888-E808-4FF5-A9D4-E66B00FE4A5F</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="86">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0086_UltraII Filter0000.ome.tif">urn:uuid:4EBA7220-52EC-45E0-9A54-83946E8A075C</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="86">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0086_UltraII Filter0000.ome.tif">urn:uuid:00664832-3ACF-4BB8-8E38-AC405990ABD2</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="87">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0087_UltraII Filter0000.ome.tif">urn:uuid:8066258D-1743-454D-B062-441207FB2098</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="87">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0087_UltraII Filter0000.ome.tif">urn:uuid:25A55C90-1C13-46DE-9B72-584F33E6442A</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="88">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0088_UltraII Filter0000.ome.tif">urn:uuid:4AA730FE-214F-455E-987A-C1E13E529DF4</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="88">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0088_UltraII Filter0000.ome.tif">urn:uuid:662240F6-8836-479F-B10C-86FFFF1528D8</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="89">
#
#
# 				<ns0:UUID FileName="16-57-24_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0089_UltraII Filter0000.ome.tif">urn:uuid:44C8374C-8AF4-44B7-ADCC-3620D93FD16B</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="89">
#
#
# ...
#
#
# 			<ns0:prop Value="0" fname="xyz-Table ZParkPosNeg" label="xyz-Table Z Stage Park Position Negative Direction" nId="262149" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev2step3" label="UltraII DeviceSteps_2" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_2" fname="UltraII dev14step2name" label="UltraII Position_2" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="2318.812,47.000;-41.188,64.000&amp;#58;-&amp;#58;-&amp;#58;" fname="xyz-Table PowerIncrData" label="xyz-Table Power Increment Diagram Data" nId="524293" nTy="5"/>
#
#
# 			<ns0:prop Value="0.000000" fname="xyz-Table XPosList1" label="xyz-Table Pos2 X" nId="524293" nTy="3"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII AttenuatorPower8" label="UltraII AttenuatorPower_8" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0.000000" fname="UltraII FilterFix" label="UltraII Filter Fixpoint" nId="524292" nTy="3"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII EomPowerMin7" label="UltraII EomPowerMin_7" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0.000000" fname="UltraII XFix" label="UltraII X Fixpoint" nId="524292" nTy="3"/>
#
#
# 			<ns0:prop Value="4" fname="UltraII ListLaser8" label="UltraII Laser_8" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_8" fname="UltraII dev1step8name" label="UltraII Position_8" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="Time Fastmode" label="Time Fastmode" nId="524291" nTy="2"/>
#
#
# 			<ns0:prop Value="1" fname="xyz-Table ExtendDlg" label="xyz-Table Extend Dialog" nId="262149" nTy="2"/>
#
#
# 			<ns0:prop Value="90" fname="UltraII ImgRotation" label="UltraII Image Rotation" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev17step2" label="UltraII DeviceSteps_17" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="1" fname="AutosaveThd" label="Autosave Third Axis" nId="524289" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner BchGain1" label="BeamCombiner Bleaching Gain 1" nId="524296" nTy="2"/>
#
#
# 			<ns0:prop Value="4" fname="BeamCombiner Eom4ShutterNr" label="BeamCombiner Eom4ShutterNr" nId="262152" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_2" fname="UltraII dev16step2name" label="UltraII Position_2" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="Position_0" fname="UltraII dev10step0name" label="UltraII Position_0" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII LeftBlendPos" label="UltraII Position of Left Blendslider" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev2step8" label="UltraII DeviceSteps_2" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev0step8" label="UltraII DeviceSteps_0" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="2300" fname="UltraII AttenuatorPower3" label="UltraII AttenuatorPower_3" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner SliderImg7" label="BeamCombiner Slider Image 7" nId="524296" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="xyz-Table AdditionalWaitTime" label="xyz-Table Additional Wait Time" nId="262149" nTy="2"/>
#
#
# 			<ns0:prop Value="540" fname="UltraII EmWavelength0" label="UltraII EmWavelength_0" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev8step9" label="UltraII DeviceSteps_8" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="CWP" fname="ObisLaser Operation Mode3" label="ObisLaser OperationMode3" nId="262150" nTy="5"/>
#
#
# 			<ns0:prop Value="" fname="UltraII LaserName8" label="UltraII LaserName_8" nId="524292" nTy="5"/>
#
#
# 			<ns0:prop Value="Position_9" fname="UltraII dev13step9name" label="UltraII Position_9" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev13step2" label="UltraII DeviceSteps_13" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII EomPower6" label="UltraII EomPower_6" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="186" fname="UltraII TubusLensePos2" label="UltraII TubusLensePos_2" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="500" fname="xyz-Table ZParkPosNear" label="xyz-Table Z Stage Park near distance to sample" nId="262149" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev0step5" label="UltraII DeviceSteps_0" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev11step8" label="UltraII DeviceSteps_11" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="2" fname="BeamCombiner EOMMode2" label="BeamCombiner EOM Mode 2" nId="524296" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner LinkAttShutter2" label="BeamCombiner LinkAttShutter2" nId="262152" nTy="2"/>
#
#
# 			<ns0:prop Value="1.550000" fname="UltraII ReferenceRefractionIndex" label="UltraII Reference Refraction Index" nId="262148" nTy="3"/>
#
#
# 			<ns0:prop Value="785" fname="UltraII dev1step3name" label="UltraII Position_3" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev4step0" label="UltraII DeviceSteps_4" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner EomAom4" label="BeamCombiner Is_4_eom_or_aom" nId="262152" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII HorzFocusMode" label="UltraII Horz Focus Mode" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="1" fname="xyz-Table JoystickInit" label="xyz-Table Joystick active" nId="262149" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev14step1" label="UltraII DeviceSteps_14" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="  488 50C " fname="UltraII LaserName3" label="UltraII LaserName_3" nId="524292" nTy="5"/>
#
#
# 			<ns0:prop Value="-1" fname="BeamCombiner EomAttenuatorIdx3" label="BeamCombiner EomAttenuatorIdx3" nId="262152" nTy="2"/>
#
#
# 			<ns0:prop Value="3" fname="UltraII FilterComPort" label="UltraII  Filter Com Port" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_0" fname="UltraII dev0step0name" label="UltraII Position_0" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="3" fname="UltraII ListMap3" label="UltraII Map_3" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="951.791138" fname="xyz-Table XPosMin" label="xyz-Table X Start position" nId="524293" nTy="3"/>
#
#
# 			<ns0:prop Value="0.000000" fname="UltraII XOff" label="UltraII X Offset" nId="524292" nTy="3"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev3step1" label="UltraII DeviceSteps_3" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev12step0" label="UltraII DeviceSteps_12" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="xyz-Table AllowManualOffset" label="xyz-Table Allow Manual Offsets" nId="262149" nTy="2"/>
#
#
# 			<ns0:prop Value="0.000000" fname="xyz-Table YPosList3" label="xyz-Table Pos4 Y" nId="524293" nTy="3"/>
#
#
# 			<ns0:prop Value="26" fname="UltraII DeviceType" label="UltraII Device Of" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII ListFilter2" label="UltraII Filter_2" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev18step9" label="UltraII DeviceSteps_18" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="3599" fname="UltraII dev7step2" label="UltraII DeviceSteps_7" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_0" fname="UltraII dev18step0name" label="UltraII Position_0" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner EomAomMin6" label="BeamCombiner min_6_eom_or_aom" nId="262152" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="ObisLaser LaserState5" label="ObisLaser Laser State5" nId="1572870" nTy="2"/>
#
#
# 			<ns0:prop Value="empty" fname="UltraII dev7step3name" label="UltraII Position_3" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="4" fname="BeamCombiner ShutterComPort" label="BeamCombiner Shutter Com Port" nId="262152" nTy="2"/>
#
#
# 			<ns0:prop Value="122" fname="UltraII dev1step3" label="UltraII DeviceSteps_1" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev16step7" label="UltraII DeviceSteps_16" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0.000000" fname="Andor YFix" label="Andor Y Fixpoint" nId="524290" nTy="3"/>
#
#
# 			<ns0:prop Value="1" fname="UltraII FilterColor3" label="UltraII FilterColor_3" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner BCShutter2" label="BeamCombiner BeamCombiner Shutter 2" nId="524296" nTy="2"/>
#
#
# 			<ns0:prop Value="1.000000" fname="UltraII TLen" label="UltraII T Length" nId="524292" nTy="3"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev18step4" label="UltraII DeviceSteps_18" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="27.279308" fname="UltraII SheetThickness" label="UltraII Sheet thickness FWHM micron" nId="524292" nTy="3"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner FrapUseAxisPos" label="BeamCombiner FrapUseAxisPos" nId="524296" nTy="2"/>
#
#
# 			<ns0:prop Value="f(x) = 0" fname="xyz-Table PowerIncrFunc2" label="xyz-Table Power Increment Function 2" nId="524293" nTy="5"/>
#
#
# 			<ns0:prop Value="-7685.916992" fname="xyz-Table YPosMin" label="xyz-Table Y Start position" nId="524293" nTy="3"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev15step3" label="UltraII DeviceSteps_15" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner SliderBch1" label="BeamCombiner Slider Bleaching 1" nId="524296" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_6" fname="UltraII dev19step6name" label="UltraII Position_6" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev6step6" label="UltraII DeviceSteps_6" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="Blend" fname="UltraII SheetMerge" label="UltraII Sheet merge type" nId="524292" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev19step3" label="UltraII DeviceSteps_19" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="1" fname="UltraII EomChk" label="UltraII Use Eom instead of Filter" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="2415" fname="UltraII FocusStopPosRight" label="UltraII Stop position for Focus" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="empty" fname="UltraII dev9step4name" label="UltraII Position_4" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev2step6" label="UltraII DeviceSteps_2" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0.000000" fname="xyz-Table MountLen" label="xyz-Table Mount Length" nId="524293" nTy="3"/>
#
#
# 			<ns0:prop Value="Position_5" fname="UltraII dev16step5name" label="UltraII Position_5" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0.000000" fname="xyz-Table XPosList2" label="xyz-Table Pos3 X" nId="524293" nTy="3"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII EomPowerMin4" label="UltraII EomPowerMin_4" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="1" fname="Andor XBin" label="Andor  X Bin" nId="524290" nTy="2"/>
#
#
# 			<ns0:prop Value="2" fname="UltraII ListLVBTFilter5" label="UltraII LVBTFilter_5" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="Eom 6" fname="BeamCombiner eom5name" label="BeamCombiner Eom 6" nId="262152" nTy="5"/>
#
#
# 			<ns0:prop Value="Position_9" fname="UltraII dev10step9name" label="UltraII Position_9" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="50" fname="xyz-Table SleepTime" label="xyz-Table Sleep Time: extra waittime" nId="262149" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII ZoomSheetwidth" label="UltraII Zoom set sheetwidth" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="1120403456" fname="UltraII PowerInfo6" label="UltraII PowerInfo_6" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="640" fname="UltraII dev1step2name" label="UltraII Position_2" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="808.265625" fname="UltraII SheetFocusStartPixPosLeft" label="UltraII Start pix pos sheet focus left" nId="524292" nTy="3"/>
#
#
# 			<ns0:prop Value="1162.380981" fname="UltraII SheetFocusStopPixPosRight" label="UltraII Stop pix pos sheet focus right" nId="524292" nTy="3"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev17step1" label="UltraII DeviceSteps_17" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="30000" fname="Time AutofocusTimeMs" label="Time Autofocus min. time to run [ms]" nId="524291" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner BchGain2" label="BeamCombiner Bleaching Gain 2" nId="524296" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_1" fname="UltraII dev16step1name" label="UltraII Position_1" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="1" fname="BeamCombiner Eom1ShutterNr" label="BeamCombiner Eom1ShutterNr" nId="262152" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_1" fname="UltraII dev11step1name" label="UltraII Position_1" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev19step8" label="UltraII DeviceSteps_19" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_7" fname="UltraII dev10step7name" label="UltraII Position_7" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="2300" fname="UltraII AttenuatorPower0" label="UltraII AttenuatorPower_0" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="12763.636719" fname="UltraII XLen" label="UltraII X Length" nId="524292" nTy="3"/>
#
#
# 			<ns0:prop Value="0-0-0" fname="UltraII dev7step0name" label="UltraII Position_0" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="BeamCombiner SliderImg4" label="BeamCombiner Slider Image 4" nId="524296" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_9" fname="UltraII dev9step9name" label="UltraII Position_9" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="393216" fname="UltraII ListLaser0" label="UltraII Laser_0" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="488" fname="UltraII Wavelength0" label="UltraII Wavelength_0" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII FilterChk9" label="UltraII FilterChk_9" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="540" fname="UltraII EmWavelength7" label="UltraII EmWavelength_7" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII EomPowerMax4" label="UltraII EomPowerMax_4" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev8step4" label="UltraII DeviceSteps_8" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="CWP" fname="ObisLaser Operation Mode4" label="ObisLaser OperationMode4" nId="262150" nTy="5"/>
#
#
# 			<ns0:prop Value="2" fname="xyz-Table YRes" label="xyz-Table Y Resolution" nId="524293" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_2" fname="UltraII dev2step2name" label="UltraII Position_2" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev13step1" label="UltraII DeviceSteps_13" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_6" fname="UltraII dev17step6name" label="UltraII Position_6" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="Focus Left" fname="UltraII dev6name" label="UltraII UltraMotor_6" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="1" fname="Andor NumImg" label="Andor  Num. img. to average" nId="524290" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="ObisLaser Comport Laser8" label="ObisLaser ComportLaser8" nId="262150" nTy="2"/>
#
#
# 			<ns0:prop Value="empty" fname="UltraII dev1step7name" label="UltraII Position_7" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev0step0" label="UltraII DeviceSteps_0" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="xyz-Table LockOverlapXY" label="xyz-Table Lock XY Mosaic Overlap" nId="524293" nTy="2"/>
#
#
# 			<ns0:prop Value="2" fname="BeamCombiner EOMMode7" label="BeamCombiner EOM Mode 7" nId="524296" nTy="2"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev4step7" label="UltraII DeviceSteps_4" nId="262148" nTy="2"/>
#
#
# 			<ns0:prop Value="Flip-Mirror" fname="UltraII dev3name" label="UltraII UltraMotor_3" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII FilterChk4" label="UltraII FilterChk_4" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="540" fname="UltraII EmWavelength8" label="UltraII EmWavelength_8" nId="524292" nTy="2"/>
#
#
# 			<ns0:prop Value="Position_1" fname="UltraII dev18step1name" label="UltraII Position_1" nId="262148" nTy="5"/>
#
#
# 			<ns0:prop Value="0" fname="UltraII dev14step6" label="UltraII DeviceSteps_14" nId="262148" nTy="2"/>
#
#
# 		</ns0:Properties>
#
#
# 	</ns2:CustomAttributes>
#
#
# </ns0:OME>

# %% [markdown]
# ## Example: get experimenter information (netid)

# %%
# The experimenter info is in the Experimenter tag:
exp_tag = root[0]
for child in exp_tag:
    print(child,child.attrib)
# Out:
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}FirstName' at 0x7f5d5f9f1278> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}LastName' at 0x7f5d5f9f12c8> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}Email' at 0x7f5d5f9f1318> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}Institution' at 0x7f5d5f9f1368> {}

# %%
# Here we see the attrib dict is empty, so how do we actually extract the email?
email_tag = exp_tag[2]
print(dir(email_tag))
# Out:
# ['__class__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'attrib', 'clear', 'extend', 'find', 'findall', 'findtext', 'get', 'getchildren', 'getiterator', 'insert', 'items', 'iter', 'iterfind', 'itertext', 'keys', 'makeelement', 'remove', 'set', 'tag', 'tail', 'text']

# %%
email_tag.text
# Out:
# 'not_specified'

# %% [markdown]
# ## Save the metadata xml file and view it in a browser (best option for viewing)

# %%
# Just need to write the xml string to a file
import os
output_filename = 'example_lightsheet_metadata.xml'
if not os.path.exists(output_filename):
    with open(output_filename,'w') as outfile:
        outfile.write(xml_description)
print("wrote %s" % output_filename)
# Out:
# wrote example_lightsheet_metadata.xml
